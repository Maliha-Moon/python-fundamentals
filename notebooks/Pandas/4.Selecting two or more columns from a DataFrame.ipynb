# %%
import pandas as pd

# %%
# reading the csv file
df = pd.read_csv('customer.csv')
df
# Out:
#    Unnamed: 0  ID         Name  Age      City  Purchase_Amount
# 0           0   1   Customer_1   44   Chicago           175.08
# 1           1   2   Customer_2   53  New York           301.74
# 2           2   3   Customer_3   25   Houston           353.85
# 3           3   4   Customer_4   26   Phoenix           735.50
# 4           4   5   Customer_5   47   Houston           219.66
# 5           5   6   Customer_6   69   Houston           837.42
# 6           6   7   Customer_7   36   Phoenix           681.78
# 7           7   8   Customer_8   44   Houston           926.90
# 8           8   9   Customer_9   52   Houston           525.23
# 9           9  10  Customer_10   40  New York           471.29

# %% [markdown]
# # **1. Selecting 2 or more columns**

# %%
# selecting 2 columns using [[]]
df[['Name','Age']]
# Out:
#           Name  Age
# 0   Customer_1   44
# 1   Customer_2   53
# 2   Customer_3   25
# 3   Customer_4   26
# 4   Customer_5   47
# 5   Customer_6   69
# 6   Customer_7   36
# 7   Customer_8   44
# 8   Customer_9   52
# 9  Customer_10   40

# %%
# Check out the data type of the selection
type(df[['Name','Age']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 📌 Column Selection in Pandas: Series vs DataFrame
#
# #### 🔹 `df['Name']` → **Series**
# - Single bracket used
# - Selects one column
# - Returns: `pandas.Series`
#
# #### 🔹 `df[['Name']]` → **DataFrame**
# - Double brackets used
# - Selects one column, but keeps it in DataFrame format
# - Returns: `pandas.DataFrame`
#
# #### 🔹 `df[['Name', 'Age']]` → **DataFrame**
# - Double brackets used
# - Selects multiple columns
# - Returns: `pandas.DataFrame`

# %%
type(df[['City']])
# Out:
# pandas.core.frame.DataFrame

# %%
# Select more columns
df[['Name','Age','City','Purchase_Amount']]
# Out:
#           Name  Age      City  Purchase_Amount
# 0   Customer_1   44   Chicago           175.08
# 1   Customer_2   53  New York           301.74
# 2   Customer_3   25   Houston           353.85
# 3   Customer_4   26   Phoenix           735.50
# 4   Customer_5   47   Houston           219.66
# 5   Customer_6   69   Houston           837.42
# 6   Customer_7   36   Phoenix           681.78
# 7   Customer_8   44   Houston           926.90
# 8   Customer_9   52   Houston           525.23
# 9  Customer_10   40  New York           471.29
