# %% [markdown]
# # **🔍How to find missing values**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Dataset = pd.read_csv("Titanic-Dataset.csv")
Dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Dataset.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
Dataset.shape
# Out:
# (891, 12)

# %%
Dataset.isnull?
# Out:
# Signature: Dataset.isnull() -> 'DataFrame'
# Docstring:
# DataFrame.isnull is an alias for DataFrame.isna.
#
# Detect missing values.
#
# Return a boolean same-sized object indicating if the values are NA.
# NA values, such as None or :attr:`numpy.NaN`, gets mapped to True
# values.
# Everything else gets mapped to False values. Characters such as empty
# strings ``''`` or :attr:`numpy.inf` are not considered NA values
# (unless you set ``pandas.options.mode.use_inf_as_na = True``).
#
# Returns
# -------
# DataFrame
#     Mask of bool values for each element in DataFrame that
#     indicates whether an element is an NA value.
#
# See Also
# --------
# DataFrame.isnull : Alias of isna.
# DataFrame.notna : Boolean inverse of isna.
# DataFrame.dropna : Omit axes labels with missing values.
# isna : Top-level isna.
#
# Examples
# --------
# Show which entries in a DataFrame are NA.
#
# >>> df = pd.DataFrame(dict(age=[5, 6, np.nan],
# ...

# %%
# Detect missing value
Dataset.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
# Total null values in the overall dataset
Dataset.isnull().sum().sum()
# Out:
# np.int64(866)

# %%
# percentage of total missing values in the entire dataset
(Dataset.isnull().sum().sum()/ (Dataset.shape[0]*Dataset.shape[1]))*100
# Out:
# np.float64(8.099513655069211)

# %%
# get the number of missing data points per column
Dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# How much percentage of missing values in each column in the dataset
(Dataset.isnull().sum()/Dataset.shape[0])*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
# find notnull value in the entire dataset
Dataset.notnull().sum().sum()
# Out:
# np.int64(9826)

# %%
# find notnull value in each column
Dataset.notnull().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %% [markdown]
# # **📊Visualize missing value**

# %%
sns.heatmap(Dataset.isnull())
plt.show()

# %% [markdown]
# # **⚙️How to handle missing value**

# %% [markdown]
# ## **Dropping**

# %% [markdown]
# > 🪜 Delete/drop a **column** if **more than 50%** of its values are **missing**

# %% [markdown]
# Dataset.drop?

# %%
# drop 'cabin' column
# replaces/updates the original dataset in memory.
Dataset.drop(columns=['Cabin'],inplace=True)

# %%
Dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Dataset.shape
# Out:
# (891, 11)

# %%
# Visualize missing value after dropping a column
sns.heatmap(Dataset.isnull())
plt.show()

# %%
# Drop all the columns with missing values
Dataset.dropna(axis=1, inplace=True)
Dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
Dataset.shape
# Out:
# (891, 9)

# %%
# visualize missing values after removing all the columns with missing values
sns.heatmap(Dataset.isnull())
plt.show()

# %% [markdown]
# > 🎞️ Drop **rows** with **missing** value

# %%
Dataset.dropna?
# Out:
# Signature:
# Dataset.dropna(
#     *,
#     axis: 'Axis' = 0,
#     how: 'AnyAll | lib.NoDefault' = <no_default>,
#     thresh: 'int | lib.NoDefault' = <no_default>,
#     subset: 'IndexLabel | None' = None,
#     inplace: 'bool' = False,
#     ignore_index: 'bool' = False,
# ) -> 'DataFrame | None'
# Docstring:
# Remove missing values.
#
# See the :ref:`User Guide <missing_data>` for more on which values are
# considered missing, and how to work with missing data.
#
# Parameters
# ----------
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Determine if rows or columns which contain missing values are
#     removed.
#
#     * 0, or 'index' : Drop rows which contain missing values.
#     * 1, or 'columns' : Drop columns which contain missing value.
#
#     Only a single axis is allowed.
#
# how : {'any', 'all'}, default 'any'
#     Determine if row or column is removed from DataFrame, when we have
#     at least one NA or all NA.
#
# ...

# %%
# drop all the rows with missing values
Dataset.dropna(inplace=True)

# %%
Dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.heatmap(Dataset.isnull())
plt.show()

# %%
# Number of rows, columns after removing rows with missing value
Dataset.shape
# Out:
# (712, 11)

# %% [markdown]
# ### ⚠️ **Loose Data**

# %%
# Total percentage of lossing data
((819-712)/819)*100
# Out:
# 13.064713064713066

# %% [markdown]
# ## **Imputing Categorical Data**

# %% [markdown]
# ## 📝 Steps
#
# ### 1️⃣ Identify the Data Types
# - Use `.dtypes` or `info()` to check the data types of each column in the dataset.
# - This helps to distinguish between **numerical** and **categorical** features.
#
# ---
#
# ### 2️⃣ Handle Missing Values for Categorical Data
# For categorical columns with missing values, we can apply:
#
# - **Mode Imputation**
#   Replace missing values with the **most frequent value** (mode) of the column.
#
# - **Forward Fill (ffill)**
#   Fill the missing value with the **previous non-missing value**.
#
# - **Backward Fill (bfill)**
#   Fill the missing value with the **next non-missing value**.
#
# ---

# %% [markdown]
# Dataset

# %%
# Check data types
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
Dataset.fillna?
# Out:
# Signature:
# Dataset.fillna(
#     value: 'Hashable | Mapping | Series | DataFrame | None' = None,
#     *,
#     method: 'FillnaOptions | None' = None,
#     axis: 'Axis | None' = None,
#     inplace: 'bool_t' = False,
#     limit: 'int | None' = None,
#     downcast: 'dict | None | lib.NoDefault' = <no_default>,
# ) -> 'Self | None'
# Docstring:
# Fill NA/NaN values using the specified method.
#
# Parameters
# ----------
# value : scalar, dict, Series, or DataFrame
#     Value to use to fill holes (e.g. 0), alternately a
#     dict/Series/DataFrame of values specifying which value to use for
#     each index (for a Series) or column (for a DataFrame).  Values not
#     in the dict/Series/DataFrame will not be filled. This value cannot
#     be a list.
# method : {'backfill', 'bfill', 'ffill', None}, default None
#     Method to use for filling holes in reindexed Series:
#
#     * ffill: propagate last valid observation forward to next valid.
# ...

# %% [markdown]
# ### ⏪ **Backward Fill**

# %%
# Backward fill
Dataset.fillna(method = 'bfill')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18964\257214970.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Dataset.fillna(method = 'bfill')
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
# backward fill columnwise
Dataset.fillna(method = 'bfill', axis=1)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18964\3713302161.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Dataset.fillna(method = 'bfill', axis=1)
#     PassengerId Survived Pclass  \
# 0             1        0      3
# 1             2        1      1
# 2             3        1      3
# 3             4        1      1
# 4             5        0      3
# ..          ...      ...    ...
# 886         887        0      2
# 887         888        1      1
# 888         889        0      3
# 889         890        1      1
# 890         891        0      3
#
#                                                   Name     Sex   Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 2                               Heikkinen, Miss. Laina  female  26.0     0
# ...

# %% [markdown]
# ### ⏩ **Forward fill**

# %%
# Forward fill
Dataset.fillna(method = 'ffill')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18964\2535864517.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Dataset.fillna(method = 'ffill')
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
# forward fill columnwise
Dataset.fillna(method = 'ffill',axis=1)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18964\1546881127.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   Dataset.fillna(method = 'ffill',axis=1)
#     PassengerId Survived Pclass  \
# 0             1        0      3
# 1             2        1      1
# 2             3        1      3
# 3             4        1      1
# 4             5        0      3
# ..          ...      ...    ...
# 886         887        0      2
# 887         888        1      1
# 888         889        0      3
# 889         890        1      1
# 890         891        0      3
#
#                                                   Name     Sex     Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male    22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38.0     1
# 2                               Heikkinen, Miss. Laina  female    26.0     0
# ...

# %% [markdown]
# ### 🔢 **Mode Imputation**

# %% [markdown]
# **Imputation:** This technique involves filling in missing values with a **calculated estimate, such as the mean, median, or mode** of the available data. Advanced methods include **predictive modeling**, where missing values are **predicted based on relationships within the data**.

# %% [markdown]
# ### **Mode Imputation for a Particular Column**
#
# ---
#
# ### 📝 Steps:
# 1. **Identify** the column with missing values.
# 2. **Compute the mode** (most frequent value) of that column.
# 3. **Replace** all missing values (`NaN`) in the column with the computed mode.

# %%
# Select the 'Age' column & compute mode
Dataset["Age"].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
# Get actual mode value
Dataset['Age'].mode()[0]
# Out:
# np.float64(24.0)

# %%
# Fill/replace all missing values with the mode value
Dataset["Age"].fillna(Dataset["Age"].mode()[0],inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21936\600844586.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Dataset["Age"].fillna(Dataset["Age"].mode()[0],inplace=True)

# %%
Dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### **Mode Imputation for All Object (Categorical) Columns**
#
# ---
#
# #### 📝 Steps:
# 1. **Identify** all object (categorical) columns in the dataset.
# 2. **Detect** which of those columns contain missing values.
# 3. **Compute** the mode (most frequent value) for each column with missing values.
# 4. **Replace** missing values with the corresponding mode value.

# %%
# collect object type data
Dataset.select_dtypes(include='object')
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
# get column having missing values
Dataset.select_dtypes(include = 'object').isnull().sum()
# Out:
# Name          0
# Sex           0
# Ticket        0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
# list of column with object data type
Dataset.select_dtypes(include = 'object').columns
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
# fill with mode value
for i in Dataset.select_dtypes(include = 'object').columns:
    Dataset[i].fillna(Dataset[i].mode()[0], inplace=True)

# %%
Dataset.select_dtypes(include = 'object').isnull().sum() # No missing value
# Out:
# Name        0
# Sex         0
# Ticket      0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
Dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
